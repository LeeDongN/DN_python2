# %%
from matplotlib import pyplot as plt
import numpy as np
import argparse
import cv2
import glob
from copy import deepcopy

# %%
DATA_PATH = r'C:\DATA_Python\endoscope\cap_endoscope_frame'

# %%
endo_data = glob.glob(DATA_PATH + '/*.jpg')

# %%
#endo_data중 튀는 데이터 일부를 랜덤으로 추출

endo_data_list = [endo_data[0], endo_data[170], endo_data[297], endo_data[416], endo_data[583],
                  endo_data[690], endo_data[859]]

# %%
data = ['a', 'b', 'c', 'd', 'e', 'f', 'g']
data_2 = ['a1', 'b1', 'c1', 'd1', 'e1', 'f1', 'g1']

for i in range(len(endo_data_list)):
    for k in range(len(endo_data_list)):
        data[k] = cv2.imread(endo_data_list[i])
        cv2.imshow('test{}'.format(k), data[k])
        cv2.waitKey(0)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2bc323f52816> in <module>
#       6         data[k] = cv2.imread(endo_data_list[i])
#       7         cv2.imshow('test{}'.format(k), data[k])
# ----> 8         cv2.waitKey(0)
#
# KeyboardInterrupt:

# %%
test_img = cv2.imread(endo_data_list[6])

# %%
chans = cv2.split(test_img)
colors = ("b", "g", "r")
plt.figure(figsize=[10,10])
plt.title("Color Histogram")
plt.xlabel("Bins")
plt.ylabel("# of Pixcels")
plt.ylim(0, 10000)

features = []
 
for(chan, color) in zip(chans, colors):
    hist = cv2.calcHist([chan], [0], None, [256], [0, 256])
    features.extend(hist)
 
    plt.plot(hist, color = color)
    
    #r,g,b가 0인 것은 검은색으로 인지
    plt.xlim([1, 256])
 
print("Flattened feature vector size: %d " %(np.array(features).flatten().shape))
plt.show()
# Out:
# Flattened feature vector size: 768
